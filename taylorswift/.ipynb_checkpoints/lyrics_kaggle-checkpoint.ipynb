# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from textblob import TextBlob
import os
import requests
from bs4 import BeautifulSoup
import re
# %load_ext dotenv
# %dotenv
sns.set(style="darkgrid")

# %%
lyrics_df = pd.read_csv('taylor_swift_lyrics.csv', encoding= "ISO-8859-1")
lyrics_df['lyric_textblob'] = lyrics_df['lyric'].apply(lambda x: TextBlob(x))
lyrics_df['polarity'] = lyrics_df['lyric_textblob'].apply(lambda x: x.sentiment.polarity)
lyrics_df['subjectivity'] = lyrics_df['lyric_textblob'].apply(lambda x: x.sentiment.subjectivity)
lyrics_df.head()
# Out:
#          artist         album track_title  track_n  \
# 0  Taylor Swift  Taylor Swift  Tim McGraw        1
# 1  Taylor Swift  Taylor Swift  Tim McGraw        1
# 2  Taylor Swift  Taylor Swift  Tim McGraw        1
# 3  Taylor Swift  Taylor Swift  Tim McGraw        1
# 4  Taylor Swift  Taylor Swift  Tim McGraw        1
#
#                                          lyric  line  year  \
# 0          He said the way my blue eyes shined     1  2006
# 1  Put those Georgia stars to shame that night     2  2006
# 2                       I said, "That's a lie"     3  2006
# 3                  Just a boy in a Chevy truck     4  2006
# 4         That had a tendency of gettin' stuck     5  2006
#
#                                       lyric_textblob  polarity  subjectivity
# 0  (H, e,  , s, a, i, d,  , t, h, e,  , w, a, y, ...       0.0           0.1
# 1  (P, u, t,  , t, h, o, s, e,  , G, e, o, r, g, ...       0.0           0.0
# 2  (I,  , s, a, i, d, ,,  , ", T, h, a, t, ', s, ...       0.0           0.0
# 3  (J, u, s, t,  , a,  , b, o, y,  , i, n,  , a, ...       0.0           0.0
# 4  (T, h, a, t,  , h, a, d,  , a,  , t, e, n, d, ...       0.0           0.0

# %%
song_df = lyrics_df.groupby(['album','track_title'])['lyric'].apply(" ".join).reset_index()
song_df['song_textblob'] = song_df['lyric'].apply(lambda x: TextBlob(x))
song_df['polarity'] = song_df['song_textblob'].apply(lambda x: x.sentiment.polarity)
song_df['subjectivity'] = song_df['song_textblob'].apply(lambda x: x.sentiment.subjectivity)
song_df.head()
# Out:
#   album                 track_title  \
# 0  1989  All You Had to Do Was Stay
# 1  1989                   Bad Blood
# 2  1989                 Blank Space
# 3  1989                       Clean
# 4  1989        How You Get The Girl
#
#                                                lyric  \
# 0  People like you always want back The love they...
# 1  'Cause baby, now we've got bad blood You know ...
# 2  Nice to meet you, where you been? I could show...
# 3  The drought was the very worst When the flower...
# 4  Uh, uh, uh Uh, uh, uh Uh-uh, uh-uh Stand there...
#
#                                        song_textblob  polarity  subjectivity
# 0  (P, e, o, p, l, e,  , l, i, k, e,  , y, o, u, ...  0.201206      0.403947
# 1  (', C, a, u, s, e,  , b, a, b, y, ,,  , n, o, ... -0.234846      0.630275
# 2  (N, i, c, e,  , t, o,  , m, e, e, t,  , y, o, ... -0.003736      0.615789
# 3  (T, h, e,  , d, r, o, u, g, h, t,  , w, a, s, ...  0.051141      0.600347
# 4  (U, h, ,,  , u, h, ,,  , u, h,  , U, h, ,,  , ... -0.078125      0.450000

# %%
display(song_df.sort_values('polarity').head())
display(song_df.sort_values('polarity', ascending = False).head())
# Out:
#            album              track_title  \
# 9           1989             Shake It Off
# 1           1989                Bad Blood
# 72  Taylor Swift          Picture To Burn
# 37           Red  I Knew You Were Trouble
# 23      Fearless              Tell Me Why
#
#                                                 lyric  \
# 9   I stay out too late Got nothing in my brain Th...
# 1   'Cause baby, now we've got bad blood You know ...
# 72  State the obvious, I didn't get my perfect fan...
# 37  Once upon a time, a few mistakes ago I was in ...
# 23  I took a chance I took a shot And you might th...
#
#                                         song_textblob  polarity  subjectivity
# 9   (I,  , s, t, a, y,  , o, u, t,  , t, o, o,  , ... -0.482914      0.869336
# 1   (', C, a, u, s, e,  , b, a, b, y, ,,  , n, o, ... -0.234846      0.630275
# 72  (S, t, a, t, e,  , t, h, e,  , o, b, v, i, o, ... -0.199145      0.606838
# 37  (O, n, c, e,  , u, p, o, n,  , a,  , t, i, m, ... -0.196356      0.328283
# 23  (I,  , t, o, o, k,  , a,  , c, h, a, n, c, e, ... -0.190594      0.533363
#            album                              track_title  \
# 65  Taylor Swift                   A Perfectly Good Heart
# 74  Taylor Swift                           Stay Beautiful
# 12          1989                      Welcome to New York
# 21      Fearless                              Hey Stephen
# 33           Red  Everything Has Changed (Ft. Ed Sheeran)
#
#                                                 lyric  \
# 65  Why would you wanna break a perfectly good hea...
# 74  Cory's eyes are like a jungle He smiles, it's ...
# 12  Walking through a crowd, the village is aglow ...
# 21  Hey Stephen, I know looks can be deceiving But...
# 33  All I knew this morning when I woke Is I know ...
#
#                                         song_textblob  polarity  subjectivity
# 65  (W, h, y,  , w, o, u, l, d,  , y, o, u,  , w, ...  0.523529      0.525490
# 74  (C, o, r, y, ', s,  , e, y, e, s,  , a, r, e, ...  0.437351      0.672917
# 12  (W, a, l, k, i, n, g,  , t, h, r, o, u, g, h, ...  0.426636      0.658263
# 21  (H, e, y,  , S, t, e, p, h, e, n, ,,  , I,  , ...  0.353889      0.717778
# 33  (A, l, l,  , I,  , k, n, e, w,  , t, h, i, s, ...  0.339293      0.442964

# %%
# Why is Shake It Off most negative song? 
display(lyrics_df[lyrics_df['track_title'] == 'Shake It Off'].sort_values('polarity').head())
display(lyrics_df[lyrics_df['track_title'] == 'Shake It Off'].sort_values('polarity', ascending = False).head())
# Out:
#             artist album   track_title  track_n  \
# 3268  Taylor Swift  1989  Shake It Off        6
# 3248  Taylor Swift  1989  Shake It Off        6
# 3288  Taylor Swift  1989  Shake It Off        6
# 3281  Taylor Swift  1989  Shake It Off        6
# 3252  Taylor Swift  1989  Shake It Off        6
#
#                                                   lyric  line  year  \
# 3268  And the haters gonna hate, hate, hate, hate, hate    34  2014
# 3248  And the haters gonna hate, hate, hate, hate, hate    14  2014
# 3288  And the haters gonna hate, hate, hate, hate, h...    54  2014
# 3281  And dirty, dirty cheats of the world you could...    47  2014
# 3252  And the fakers gonna fake, fake, fake, fake, fake    18  2014
#
#                                          lyric_textblob  polarity  \
# 3268  (A, n, d,  , t, h, e,  , h, a, t, e, r, s,  , ...  -0.80000
# 3248  (A, n, d,  , t, h, e,  , h, a, t, e, r, s,  , ...  -0.80000
# 3288  (A, n, d,  , t, h, e,  , h, a, t, e, r, s,  , ...  -0.80000
# 3281  (A, n, d,  , d, i, r, t, y, ,,  , d, i, r, t, ...  -0.51746
# 3252  (A, n, d,  , t, h, e,  , f, a, k, e, r, s,  , ...  -0.50000
#
#       subjectivity
# 3268      0.900000
# 3248      0.900000
# 3288      0.900000
# 3281      0.686508
# 3252      1.000000
#             artist album   track_title  track_n  \
# 3284  Taylor Swift  1989  Shake It Off        6
# 3259  Taylor Swift  1989  Shake It Off        6
# 3239  Taylor Swift  1989  Shake It Off        6
# 3282  Taylor Swift  1989  Shake It Off        6
# 3271  Taylor Swift  1989  Shake It Off        6
#
#                                                   lyric  line  year  \
# 3284  And to the fella over there with the hella goo...    50  2014
# 3259          I'm dancing on my own (dancing on my own)    25  2014
# 3239                             I go on too many dates     5  2014
# 3282               My ex-man brought his new girlfriend    48  2014
# 3271  Heartbreakers gonna break, break, break, break...    37  2014
#
#                                          lyric_textblob  polarity  \
# 3284  (A, n, d,  , t, o,  , t, h, e,  , f, e, l, l, ...  0.700000
# 3259  (I, ', m,  , d, a, n, c, i, n, g,  , o, n,  , ...  0.600000
# 3239  (I,  , g, o,  , o, n,  , t, o, o,  , m, a, n, ...  0.500000
# 3282  (M, y,  , e, x, -, m, a, n,  , b, r, o, u, g, ...  0.136364
# 3271  (H, e, a, r, t, b, r, e, a, k, e, r, s,  , g, ...  0.000000
#
#       subjectivity
# 3284      0.600000
# 3259      1.000000
# 3239      0.500000
# 3282      0.454545
# 3271      0.000000

# %%
song_df.groupby(['album']).mean()
# Out:
#               polarity  subjectivity
# album
# 1989          0.054124      0.512417
# Fearless      0.095117      0.520810
# Red           0.100281      0.481302
# Speak Now     0.103686      0.467733
# Taylor Swift  0.164292      0.534923
# reputation    0.069012      0.514501

# %%
song_df['song_length'] = song_df['lyric'].apply(lambda x: len(x.split()))
song_df['song_length_unique'] = song_df['lyric'].apply(lambda x: len(set(x.split())))
song_df['uniqueness'] = song_df['song_length_unique'] / song_df['song_length']
song_df.sort_values('uniqueness').head()
display(song_df[['album','track_title','uniqueness']].sort_values('uniqueness').head())
display(song_df[['album','track_title','uniqueness']].sort_values('uniqueness', ascending = False).head())
# Out:
#          album                 track_title  uniqueness
# 8         1989            Out of the Woods    0.197853
# 6         1989            I Wish You Would    0.223801
# 90  reputation    Look What You Made Me Do    0.235189
# 0         1989  All You Had to Do Was Stay    0.242826
# 9         1989                Shake It Off    0.248739
#        album                   track_title  uniqueness
# 39       Red          Sad Beautiful Tragic    0.546448
# 16  Fearless  Breathe (Ft. Colbie Caillat)    0.538462
# 17  Fearless                        Change    0.524164
# 24  Fearless                  The Best Day    0.502841
# 41       Red                State of Grace    0.493506

# %%
# Set parameters to call API
genius_token=os.getenv("GENIUS_TOKEN")
base_url = "http://api.genius.com"
value = 'Bearer ' + genius_token
headers= {'Authorization': value}

# %%
search_url = base_url + "/search"
artist_name = "Taylor Swift"
params = {'q': artist_name}
response = requests.get(search_url, params = params, headers=headers)
response_data = response.json()
response_data
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 13,
#      'api_path': '/songs/3210592',
#      'full_title': 'Look What You Made Me Do by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/4303d8c0fc0321cc9c7e591ac30722b4.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/4303d8c0fc0321cc9c7e591ac30722b4.699x699x1.jpg',
#      'id': 3210592,
#      'lyrics_owner_id': 2171344,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-look-what-you-made-me-do-lyrics',
#      'pyongs_count': 182,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/bcd1ae9927c14b71b487d00cb4fa1b8c.300x300x1.png',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 0,
#       'pageviews': 1444574},
#      'title': 'Look What You Made Me Do',
#      'title_with_featured': 'Look What You Made Me Do',
#      'url': 'https://genius.com/Taylor-swift-look-what-you-made-me-do-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 22,
#      'api_path': '/songs/3281773',
#      'full_title': 'End Game by\xa0Taylor\xa0Swift (Ft.\xa0Ed\xa0Sheeran & Future)',
#      'header_image_thumbnail_url': 'https://images.genius.com/5c8131af7d5d20f3c8f296538af74308.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5c8131af7d5d20f3c8f296538af74308.1000x1000x1.jpg',
#      'id': 3281773,
#      'lyrics_owner_id': 93685,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-end-game-lyrics',
#      'pyongs_count': 78,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/34b696717e887f4e48070ace0fa6971b.300x300x1.jpg',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 1,
#       'pageviews': 1294323},
#      'title': 'End Game',
#      'title_with_featured': 'End Game (Ft.\xa0Ed\xa0Sheeran & Future)',
#      'url': 'https://genius.com/Taylor-swift-end-game-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 9,
#      'api_path': '/songs/3221550',
#      'full_title': '...Ready for It? by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/5c8131af7d5d20f3c8f296538af74308.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5c8131af7d5d20f3c8f296538af74308.1000x1000x1.jpg',
#      'id': 3221550,
#      'lyrics_owner_id': 1873201,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-ready-for-it-lyrics',
#      'pyongs_count': 121,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/5aeff71a5f148ca52f0b19d92a701246.300x300x1.jpg',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 0,
#       'pageviews': 1126177},
#      'title': '...Ready for It?',
#      'title_with_featured': '...Ready for It?',
#      'url': 'https://genius.com/Taylor-swift-ready-for-it-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/1866151',
#      'full_title': 'Bad Blood (Remix) by\xa0Taylor\xa0Swift (Ft.\xa0Kendrick\xa0Lamar)',
#      'header_image_thumbnail_url': 'https://images.genius.com/4525824c81e021102429c9665b14c0b7.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/4525824c81e021102429c9665b14c0b7.1000x1000x1.jpg',
#      'id': 1866151,
#      'lyrics_owner_id': 104344,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-bad-blood-remix-lyrics',
#      'pyongs_count': 610,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/4525824c81e021102429c9665b14c0b7.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 917693},
#      'title': 'Bad Blood (Remix)',
#      'title_with_featured': 'Bad Blood (Remix) (Ft.\xa0Kendrick\xa0Lamar)',
#      'url': 'https://genius.com/Taylor-swift-bad-blood-remix-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 24,
#      'api_path': '/songs/542389',
#      'full_title': 'Blank Space by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/349a53626e0af123d526530373381b79.300x300x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/349a53626e0af123d526530373381b79.1000x1000x1.jpg',
#      'id': 542389,
#      'lyrics_owner_id': 172030,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-blank-space-lyrics',
#      'pyongs_count': 969,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/eb811cfbca7ffdc3527e156e85fd78af.300x300x1.png',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 952357},
#      'title': 'Blank Space',
#      'title_with_featured': 'Blank Space',
#      'url': 'https://genius.com/Taylor-swift-blank-space-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 20,
#      'api_path': '/songs/3300013',
#      'full_title': 'Call It What You Want by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/6511b509fc5c424c4c0cbe5e7e2c7b94.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/6511b509fc5c424c4c0cbe5e7e2c7b94.1000x1000x1.jpg',
#      'id': 3300013,
#      'lyrics_owner_id': 3499957,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-call-it-what-you-want-lyrics',
#      'pyongs_count': 59,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/75f158769570b17de3f0bba057a6fbcb.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 2, 'pageviews': 868582},
#      'title': 'Call It What You Want',
#      'title_with_featured': 'Call It What You Want',
#      'url': 'https://genius.com/Taylor-swift-call-it-what-you-want-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 4,
#      'api_path': '/songs/2927948',
#      'full_title': "I Don't Wanna Live Forever by\xa0ZAYN\xa0& Taylor Swift",
#      'header_image_thumbnail_url': 'https://images.genius.com/5fb58a678999e51ce9af06a799a0f857.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/5fb58a678999e51ce9af06a799a0f857.752x752x1.jpg',
#      'id': 2927948,
#      'lyrics_owner_id': 93685,
#      'lyrics_state': 'complete',
#      'path': '/Zayn-and-taylor-swift-i-dont-wanna-live-forever-lyrics',
#      'pyongs_count': 62,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/734ece38e8ab973f353e6c3beaea915a.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 851015},
#      'title': "I Don't Wanna Live Forever",
#      'title_with_featured': "I Don't Wanna Live Forever",
#      'url': 'https://genius.com/Zayn-and-taylor-swift-i-dont-wanna-live-forever-lyrics',
#      'primary_artist': {'api_path': '/artists/1043198',
#       'header_image_url': 'https://images.genius.com/11377ef772e4bb77f0fd6faab870ac80.1000x1000x1.jpg',
#       'id': 1043198,
#       'image_url': 'https://images.genius.com/11377ef772e4bb77f0fd6faab870ac80.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'ZAYN & Taylor Swift',
#       'url': 'https://genius.com/artists/Zayn-and-taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/4472545',
#      'full_title': 'ME! by\xa0Taylor\xa0Swift (Ft.\xa0Brendon\xa0Urie)',
#      'header_image_thumbnail_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.300x168x1.jpg',
#      'header_image_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.640x359x1.jpg',
#      'id': 4472545,
#      'lyrics_owner_id': 93685,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-me-lyrics',
#      'pyongs_count': 72,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 0,
#       'concurrents': 24,
#       'pageviews': 879102},
#      'title': 'ME!',
#      'title_with_featured': 'ME! (Ft.\xa0Brendon\xa0Urie)',
#      'url': 'https://genius.com/Taylor-swift-me-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 14,
#      'api_path': '/songs/3283025',
#      'full_title': 'Delicate by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/8744ca8fb3d8f87d435929a092d42c47.300x300x1.png',
#      'header_image_url': 'https://images.genius.com/8744ca8fb3d8f87d435929a092d42c47.594x594x1.png',
#      'id': 3283025,
#      'lyrics_owner_id': 104344,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-delicate-lyrics',
#      'pyongs_count': 69,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/06bbda3eb2a8a9291d3f13ed28b55114.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 835318},
#      'title': 'Delicate',
#      'title_with_featured': 'Delicate',
#      'url': 'https://genius.com/Taylor-swift-delicate-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 16,
#      'api_path': '/songs/542390',
#      'full_title': 'Style by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.rapgenius.com/349a53626e0af123d526530373381b79.300x300x1.jpg',
#      'header_image_url': 'https://images.rapgenius.com/349a53626e0af123d526530373381b79.1000x1000x1.jpg',
#      'id': 542390,
#      'lyrics_owner_id': 258143,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-style-lyrics',
#      'pyongs_count': 979,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/b9164869778f4f40230d599880b7bfc8.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'pageviews': 756569},
#      'title': 'Style',
#      'title_with_featured': 'Style',
#      'url': 'https://genius.com/Taylor-swift-style-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}}]}}

# %%
taylor_swift_id = response_data['response']['hits'][0]['result']['primary_artist']['id']
taylor_swift_id
# Out:
# 1177

# %%
search_query = 'taylor swift me'
song_title = "ME!"
params = {'q': search_query}
response = requests.get(search_url, params = params, headers=headers)
response_data = response.json()
response_data
# Out:
# {'meta': {'status': 200},
#  'response': {'hits': [{'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/4472545',
#      'full_title': 'ME! by\xa0Taylor\xa0Swift (Ft.\xa0Brendon\xa0Urie)',
#      'header_image_thumbnail_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.300x168x1.jpg',
#      'header_image_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.640x359x1.jpg',
#      'id': 4472545,
#      'lyrics_owner_id': 93685,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-me-lyrics',
#      'pyongs_count': 72,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#      'stats': {'hot': False,
#       'unreviewed_annotations': 0,
#       'concurrents': 24,
#       'pageviews': 879102},
#      'title': 'ME!',
#      'title_with_featured': 'ME! (Ft.\xa0Brendon\xa0Urie)',
#      'url': 'https://genius.com/Taylor-swift-me-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 12,
#      'api_path': '/songs/132654',
#      'full_title': 'Mean by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/fcb0e47a5e27f575dc30b5f2d3c9f36a.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/fcb0e47a5e27f575dc30b5f2d3c9f36a.1000x1000x1.jpg',
#      'id': 132654,
#      'lyrics_owner_id': 134437,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-mean-lyrics',
#      'pyongs_count': 25,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/87d58999e9588f29f00b796fe7e828c0.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 1, 'pageviews': 67561},
#      'title': 'Mean',
#      'title_with_featured': 'Mean',
#      'url': 'https://genius.com/Taylor-swift-mean-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/216574',
#      'full_title': 'Taylor Swift Medley by\xa0Timeflies',
#      'header_image_thumbnail_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.1000x1000x1.jpg',
#      'id': 216574,
#      'lyrics_owner_id': 282518,
#      'lyrics_state': 'complete',
#      'path': '/Timeflies-taylor-swift-medley-lyrics',
#      'pyongs_count': 3,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Taylor Swift Medley',
#      'title_with_featured': 'Taylor Swift Medley',
#      'url': 'https://genius.com/Timeflies-taylor-swift-medley-lyrics',
#      'primary_artist': {'api_path': '/artists/14205',
#       'header_image_url': 'https://images.genius.com/a177b4b3256eabba044975713c062ddf.1000x375x1.jpg',
#       'id': 14205,
#       'image_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': True,
#       'name': 'Timeflies',
#       'url': 'https://genius.com/artists/Timeflies',
#       'iq': 1349}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/2466710',
#      'full_title': 'Me and Britney by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.500x500x1.jpg',
#      'id': 2466710,
#      'lyrics_owner_id': 3160336,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-me-and-britney-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 1},
#      'title': 'Me and Britney',
#      'title_with_featured': 'Me and Britney',
#      'url': 'https://genius.com/Taylor-swift-me-and-britney-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 1,
#      'api_path': '/songs/2341158',
#      'full_title': 'Taylor Swift Medley by\xa0AJ\xa0Rafael (Ft.\xa0Tori\xa0Kelly)',
#      'header_image_thumbnail_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#      'id': 2341158,
#      'lyrics_owner_id': 2407931,
#      'lyrics_state': 'complete',
#      'path': '/Aj-rafael-taylor-swift-medley-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Taylor Swift Medley',
#      'title_with_featured': 'Taylor Swift Medley (Ft.\xa0Tori\xa0Kelly)',
#      'url': 'https://genius.com/Aj-rafael-taylor-swift-medley-lyrics',
#      'primary_artist': {'api_path': '/artists/362713',
#       'header_image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#       'id': 362713,
#       'image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'AJ Rafael',
#       'url': 'https://genius.com/artists/Aj-rafael'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/4517610',
#      'full_title': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics by\xa0Taylor\xa0Swift',
#      'header_image_thumbnail_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.320x320x1.jpg',
#      'id': 4517610,
#      'lyrics_owner_id': 8316489,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-taylor-swift-me-feat-brendon-urie-of-panic-at-the-disco-lyrics-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0, 'concurrents': 2},
#      'title': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics',
#      'title_with_featured': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics',
#      'url': 'https://genius.com/Taylor-swift-taylor-swift-me-feat-brendon-urie-of-panic-at-the-disco-lyrics-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/4507508',
#      'full_title': 'Taylor Swift - ME! [Korean Translation] by\xa0Genius\xa0Translations (Ft.\xa0Brendon\xa0Urie)',
#      'header_image_thumbnail_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.600x600x1.jpg',
#      'id': 4507508,
#      'lyrics_owner_id': 2557222,
#      'lyrics_state': 'complete',
#      'path': '/Genius-translations-taylor-swift-me-korean-translation-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Taylor Swift - ME! [Korean Translation]',
#      'title_with_featured': 'Taylor Swift - ME! [Korean Translation] (Ft.\xa0Brendon\xa0Urie)',
#      'url': 'https://genius.com/Genius-translations-taylor-swift-me-korean-translation-lyrics',
#      'primary_artist': {'api_path': '/artists/1240266',
#       'header_image_url': 'https://images.genius.com/7eeefc1f26d079efea65e0fe31971b2f.900x176x1.jpg',
#       'id': 1240266,
#       'image_url': 'https://images.genius.com/d621467e52ec2b6fe5cb6d0a41846e69.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Genius Translations',
#       'url': 'https://genius.com/artists/Genius-translations'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/4511486',
#      'full_title': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse) by\xa0Genius\xa0Translations',
#      'header_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#      'header_image_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.1000x1000x1.jpg',
#      'id': 4511486,
#      'lyrics_owner_id': 6219124,
#      'lyrics_state': 'complete',
#      'path': '/Genius-translations-taylor-swift-me-ft-brendon-urie-dansk-oversttelse-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse)',
#      'title_with_featured': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse)',
#      'url': 'https://genius.com/Genius-translations-taylor-swift-me-ft-brendon-urie-dansk-oversttelse-lyrics',
#      'primary_artist': {'api_path': '/artists/1240266',
#       'header_image_url': 'https://images.genius.com/7eeefc1f26d079efea65e0fe31971b2f.900x176x1.jpg',
#       'id': 1240266,
#       'image_url': 'https://images.genius.com/d621467e52ec2b6fe5cb6d0a41846e69.1000x1000x1.png',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Genius Translations',
#       'url': 'https://genius.com/artists/Genius-translations'}}},
#    {'highlights': [],
#     'index': 'song',
#     'type': 'song',
#     'result': {'annotation_count': 0,
#      'api_path': '/songs/4523332',
#      'full_title': 'ME! (Miles Away Remix) by\xa0Taylor\xa0Swift (Ft.\xa0Brendon\xa0Urie)',
#      'header_image_thumbnail_url': 'https://images.genius.com/cf791b8563f0fb85387b1408671802b7.300x212x1.jpg',
#      'header_image_url': 'https://images.genius.com/cf791b8563f0fb85387b1408671802b7.1000x707x1.jpg',
#      'id': 4523332,
#      'lyrics_owner_id': 7018092,
#      'lyrics_state': 'complete',
#      'path': '/Taylor-swift-me-miles-away-remix-lyrics',
#      'pyongs_count': None,
#      'song_art_image_thumbnail_url': 'https://images.genius.com/467a8675409afd5a2edc8459c415e1f2.300x300x1.jpg',
#      'stats': {'hot': False, 'unreviewed_annotations': 0},
#      'title': 'ME! (Miles Away Remix)',
#      'title_with_featured': 'ME! (Miles Away Remix) (Ft.\xa0Brendon\xa0Urie)',
#      'url': 'https://genius.com/Taylor-swift-me-miles-away-remix-lyrics',
#      'primary_artist': {'api_path': '/artists/1177',
#       'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#       'id': 1177,
#       'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#       'is_meme_verified': False,
#       'is_verified': False,
#       'name': 'Taylor Swift',
#       'url': 'https://genius.com/artists/Taylor-swift'}}}]}}

# %%
# response_data['response']['hits']
# response_data['response']['hits'][0]['result']['title']
for i in response_data['response']['hits']:
    if i['result']['title'] == song_title:
        url = i['result']['url']
page = requests.get(url)
html = BeautifulSoup(page.text, "html.parser") # Extract the page's HTML as a string
lyrics = html.find("div", class_="lyrics").get_text()
# print(lyrics)
regex = re.compile("\[.*?\]")
result = re.sub(regex, "",lyrics)
result = result.replace("(","")
result = result.replace(")","")
me_words = result.split()
me_unique = set(me_words)
uniqueness = len(me_unique)/len(me_words)

print("Uniqueness: " + str(uniqueness))


# for i in result:
#     print(i)
#     lyrics.replace(i,"")
#     print(lyrics)
# print(lyrics)
# Out:
# Uniqueness: 0.2929936305732484

# %%
response_data['response']['hits']
# Out:
# [{'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 12,
#    'api_path': '/songs/4472545',
#    'full_title': 'ME! by\xa0Taylor\xa0Swift (Ft.\xa0Brendon\xa0Urie)',
#    'header_image_thumbnail_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.300x168x1.jpg',
#    'header_image_url': 'https://images.genius.com/91801b3ad216d08b77b40447cb4d1b9f.640x359x1.jpg',
#    'id': 4472545,
#    'lyrics_owner_id': 93685,
#    'lyrics_state': 'complete',
#    'path': '/Taylor-swift-me-lyrics',
#    'pyongs_count': 72,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#    'stats': {'hot': False,
#     'unreviewed_annotations': 0,
#     'concurrents': 24,
#     'pageviews': 879102},
#    'title': 'ME!',
#    'title_with_featured': 'ME! (Ft.\xa0Brendon\xa0Urie)',
#    'url': 'https://genius.com/Taylor-swift-me-lyrics',
#    'primary_artist': {'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taylor Swift',
#     'url': 'https://genius.com/artists/Taylor-swift'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 12,
#    'api_path': '/songs/132654',
#    'full_title': 'Mean by\xa0Taylor\xa0Swift',
#    'header_image_thumbnail_url': 'https://images.genius.com/fcb0e47a5e27f575dc30b5f2d3c9f36a.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/fcb0e47a5e27f575dc30b5f2d3c9f36a.1000x1000x1.jpg',
#    'id': 132654,
#    'lyrics_owner_id': 134437,
#    'lyrics_state': 'complete',
#    'path': '/Taylor-swift-mean-lyrics',
#    'pyongs_count': 25,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/87d58999e9588f29f00b796fe7e828c0.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 1, 'pageviews': 67561},
#    'title': 'Mean',
#    'title_with_featured': 'Mean',
#    'url': 'https://genius.com/Taylor-swift-mean-lyrics',
#    'primary_artist': {'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taylor Swift',
#     'url': 'https://genius.com/artists/Taylor-swift'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 1,
#    'api_path': '/songs/216574',
#    'full_title': 'Taylor Swift Medley by\xa0Timeflies',
#    'header_image_thumbnail_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.1000x1000x1.jpg',
#    'id': 216574,
#    'lyrics_owner_id': 282518,
#    'lyrics_state': 'complete',
#    'path': '/Timeflies-taylor-swift-medley-lyrics',
#    'pyongs_count': 3,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Taylor Swift Medley',
#    'title_with_featured': 'Taylor Swift Medley',
#    'url': 'https://genius.com/Timeflies-taylor-swift-medley-lyrics',
#    'primary_artist': {'api_path': '/artists/14205',
#     'header_image_url': 'https://images.genius.com/a177b4b3256eabba044975713c062ddf.1000x375x1.jpg',
#     'id': 14205,
#     'image_url': 'https://images.genius.com/4247a58c8280c18d7f89f2e46542d4f9.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': 'Timeflies',
#     'url': 'https://genius.com/artists/Timeflies',
#     'iq': 1349}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 1,
#    'api_path': '/songs/2466710',
#    'full_title': 'Me and Britney by\xa0Taylor\xa0Swift',
#    'header_image_thumbnail_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.500x500x1.jpg',
#    'id': 2466710,
#    'lyrics_owner_id': 3160336,
#    'lyrics_state': 'complete',
#    'path': '/Taylor-swift-me-and-britney-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/d4078ba0cb417196737a2a0e10327ae6.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 1},
#    'title': 'Me and Britney',
#    'title_with_featured': 'Me and Britney',
#    'url': 'https://genius.com/Taylor-swift-me-and-britney-lyrics',
#    'primary_artist': {'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taylor Swift',
#     'url': 'https://genius.com/artists/Taylor-swift'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 1,
#    'api_path': '/songs/2341158',
#    'full_title': 'Taylor Swift Medley by\xa0AJ\xa0Rafael (Ft.\xa0Tori\xa0Kelly)',
#    'header_image_thumbnail_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#    'id': 2341158,
#    'lyrics_owner_id': 2407931,
#    'lyrics_state': 'complete',
#    'path': '/Aj-rafael-taylor-swift-medley-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Taylor Swift Medley',
#    'title_with_featured': 'Taylor Swift Medley (Ft.\xa0Tori\xa0Kelly)',
#    'url': 'https://genius.com/Aj-rafael-taylor-swift-medley-lyrics',
#    'primary_artist': {'api_path': '/artists/362713',
#     'header_image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#     'id': 362713,
#     'image_url': 'https://images.genius.com/53236c05498c3ba494b35f49c95fe937.900x900x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'AJ Rafael',
#     'url': 'https://genius.com/artists/Aj-rafael'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/4517610',
#    'full_title': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics by\xa0Taylor\xa0Swift',
#    'header_image_thumbnail_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.320x320x1.jpg',
#    'id': 4517610,
#    'lyrics_owner_id': 8316489,
#    'lyrics_state': 'complete',
#    'path': '/Taylor-swift-taylor-swift-me-feat-brendon-urie-of-panic-at-the-disco-lyrics-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/76e47222ffe736cdc21becc0038e9c88.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0, 'concurrents': 2},
#    'title': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics',
#    'title_with_featured': 'Taylor Swift - Me! (Feat. Brendon Urie Of Panic! At The Disco)_Lyrics',
#    'url': 'https://genius.com/Taylor-swift-taylor-swift-me-feat-brendon-urie-of-panic-at-the-disco-lyrics-lyrics',
#    'primary_artist': {'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taylor Swift',
#     'url': 'https://genius.com/artists/Taylor-swift'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/4507508',
#    'full_title': 'Taylor Swift - ME! [Korean Translation] by\xa0Genius\xa0Translations (Ft.\xa0Brendon\xa0Urie)',
#    'header_image_thumbnail_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.600x600x1.jpg',
#    'id': 4507508,
#    'lyrics_owner_id': 2557222,
#    'lyrics_state': 'complete',
#    'path': '/Genius-translations-taylor-swift-me-korean-translation-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/af4896e12e3856c07cd40bbf6424dcc3.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Taylor Swift - ME! [Korean Translation]',
#    'title_with_featured': 'Taylor Swift - ME! [Korean Translation] (Ft.\xa0Brendon\xa0Urie)',
#    'url': 'https://genius.com/Genius-translations-taylor-swift-me-korean-translation-lyrics',
#    'primary_artist': {'api_path': '/artists/1240266',
#     'header_image_url': 'https://images.genius.com/7eeefc1f26d079efea65e0fe31971b2f.900x176x1.jpg',
#     'id': 1240266,
#     'image_url': 'https://images.genius.com/d621467e52ec2b6fe5cb6d0a41846e69.1000x1000x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Genius Translations',
#     'url': 'https://genius.com/artists/Genius-translations'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/4511486',
#    'full_title': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse) by\xa0Genius\xa0Translations',
#    'header_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.1000x1000x1.jpg',
#    'id': 4511486,
#    'lyrics_owner_id': 6219124,
#    'lyrics_state': 'complete',
#    'path': '/Genius-translations-taylor-swift-me-ft-brendon-urie-dansk-oversttelse-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/6a69d583d0d2f5cbeecedbcc60b9f382.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse)',
#    'title_with_featured': 'Taylor Swift - ME! ft. Brendon Urie (Dansk Oversættelse)',
#    'url': 'https://genius.com/Genius-translations-taylor-swift-me-ft-brendon-urie-dansk-oversttelse-lyrics',
#    'primary_artist': {'api_path': '/artists/1240266',
#     'header_image_url': 'https://images.genius.com/7eeefc1f26d079efea65e0fe31971b2f.900x176x1.jpg',
#     'id': 1240266,
#     'image_url': 'https://images.genius.com/d621467e52ec2b6fe5cb6d0a41846e69.1000x1000x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Genius Translations',
#     'url': 'https://genius.com/artists/Genius-translations'}}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 0,
#    'api_path': '/songs/4523332',
#    'full_title': 'ME! (Miles Away Remix) by\xa0Taylor\xa0Swift (Ft.\xa0Brendon\xa0Urie)',
#    'header_image_thumbnail_url': 'https://images.genius.com/cf791b8563f0fb85387b1408671802b7.300x212x1.jpg',
#    'header_image_url': 'https://images.genius.com/cf791b8563f0fb85387b1408671802b7.1000x707x1.jpg',
#    'id': 4523332,
#    'lyrics_owner_id': 7018092,
#    'lyrics_state': 'complete',
#    'path': '/Taylor-swift-me-miles-away-remix-lyrics',
#    'pyongs_count': None,
#    'song_art_image_thumbnail_url': 'https://images.genius.com/467a8675409afd5a2edc8459c415e1f2.300x300x1.jpg',
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'ME! (Miles Away Remix)',
#    'title_with_featured': 'ME! (Miles Away Remix) (Ft.\xa0Brendon\xa0Urie)',
#    'url': 'https://genius.com/Taylor-swift-me-miles-away-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/1177',
#     'header_image_url': 'https://images.genius.com/5923e08c0f81c547dae983ebb9b17e52.1000x429x1.jpg',
#     'id': 1177,
#     'image_url': 'https://images.genius.com/ae7c9cd43bc34b7c3414cd06d2b85a9b.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taylor Swift',
#     'url': 'https://genius.com/artists/Taylor-swift'}}}]

# %%
me_df = pd.DataFrame([['ME!','ME!'," ".join(me_words),TextBlob(" ".join(me_words)),TextBlob(" ".join(me_words)).sentiment.polarity,TextBlob(" ".join(me_words)).sentiment.subjectivity,len(me_words),len(me_words),uniqueness]],columns = song_df.columns)
song_df = song_df.append(me_df)
song_df
# Out:
#            album                            track_title  \
# 0           1989             All You Had to Do Was Stay
# 1           1989                              Bad Blood
# 2           1989                            Blank Space
# 3           1989                                  Clean
# 4           1989                   How You Get The Girl
# 5           1989                          I Know Places
# 6           1989                       I Wish You Would
# 7           1989                          New Romantics
# 8           1989                       Out of the Woods
# 9           1989                           Shake It Off
# 10          1989                                  Style
# 11          1989                              This Love
# 12          1989                    Welcome to New York
# 13          1989                         Wildest Dreams
# 14          1989                             Wonderland
# 15          1989                        You Are in Love
# 16      Fearless           Breathe (Ft. Colbie Caillat)
# 17      Fearless                                 Change
# 18      Fearless                               Fearless
# 19      Fearless                                Fifteen
# 20      Fearless                       Forever & Always
# 21      Fearless                            Hey Stephen
# 22      Fearless                             Love Story
# 23      Fearless                            Tell Me Why
# 24      Fearless                           The Best Day
# 25      Fearless                    The Way I Loved You
# 26      Fearless                            White Horse
# 27      Fearless                     You Belong With Me
# 28      Fearless                       You're Not Sorry
# 29           Red                                     22
# ..           ...                                    ...
# 65  Taylor Swift                 A Perfectly Good Heart
# 66  Taylor Swift                  A Place In This World
# 67  Taylor Swift                            Cold as You
# 68  Taylor Swift          I'm Only Me When I'm With You
# 69  Taylor Swift                              Invisible
# 70  Taylor Swift              Mary's Song (Oh My My My)
# 71  Taylor Swift                               Our Song
# 72  Taylor Swift                        Picture To Burn
# 73  Taylor Swift                      Should've Said No
# 74  Taylor Swift                         Stay Beautiful
# 75  Taylor Swift                 Teardrops On My Guitar
# 76  Taylor Swift                            The Outside
# 77  Taylor Swift             Tied Together With A Smile
# 78  Taylor Swift                             Tim McGraw
# 79    reputation                       ...Ready for It?
# 80    reputation                  Call It What You Want
# 81    reputation            Dancing With Our Hands Tied
# 82    reputation                               Delicate
# 83    reputation                         Don't Blame Me
# 84    reputation                                  Dress
# 85    reputation     End Game (Ft. Ed Sheeran & Future)
# 86    reputation                            Getaway Car
# 87    reputation                               Gorgeous
# 88    reputation                    I Did Something Bad
# 89    reputation                       King of My Heart
# 90    reputation               Look What You Made Me Do
# 91    reputation                         New Year's Day
# 92    reputation                          So It Goes...
# 93    reputation  This Is Why We Can't Have Nice Things
# 0            ME!                                    ME!
#
#                                                 lyric  \
# 0   People like you always want back The love they...
# 1   'Cause baby, now we've got bad blood You know ...
# 2   Nice to meet you, where you been? I could show...
# 3   The drought was the very worst When the flower...
# 4   Uh, uh, uh Uh, uh, uh Uh-uh, uh-uh Stand there...
# 5   You stand with your hand on my waistline It's ...
# 6   It's 2:00 AM, in your car Windows down, you pa...
# 7   We're all bored, we're all so tired of everyth...
# 8   Looking at it now It all seems so simple We we...
# 9   I stay out too late Got nothing in my brain Th...
# 10  Midnight You come and pick me up, no headlight...
# 11  Clear blue water, high tides came and brought ...
# 12  Walking through a crowd, the village is aglow ...
# 13  He said, "Let's get out of this town Drive out...
# 14  Flashing lights and we Took a wrong turn and w...
# 15  One look, dark room, meant just for you Time m...
# 16  I see your face in my mind as I drive away 'Ca...
# 17  And it's a sad picture, the final blow hits yo...
# 18  There's something 'bout the way The street loo...
# 19  You take a deep breath and you walk through th...
# 20  Once upon a time I believe it was a Tuesday wh...
# 21  Hey Stephen, I know looks can be deceiving But...
# 22  We were both young when I first saw you I clos...
# 23  I took a chance I took a shot And you might th...
# 24  I'm five years old, it's getting cold, I've go...
# 25  He is sensible and so incredible And all my si...
# 26  Say you're sorry, that face of an angel Comes ...
# 27  You're on the phone with your girlfriend, she'...
# 28  All this time I was wasting hoping you would c...
# 29  It feels like a perfect night to dress up like...
# ..                                                ...
# 65  Why would you wanna break a perfectly good hea...
# 66  I don't know what I want, so don't ask me Caus...
# 67  You have a way of coming easily to me And when...
# 68  Friday night beneath the stars In a field behi...
# 69  She can't see the way your eyes Light up when ...
# 70  She said, I was seven and you were nine I look...
# 71  I was riding shotgun with my hair undone In th...
# 72  State the obvious, I didn't get my perfect fan...
# 73  It's strange to think the songs we used to sin...
# 74  Cory's eyes are like a jungle He smiles, it's ...
# 75  Drew looks at me I fake a smile so he won't se...
# 76  I didn't know what I would find When I went lo...
# 77  Seems the only one who doesn't see your beauty...
# 78  He said the way my blue eyes shined Put those ...
# 79  Knew he was a killer first time that I saw him...
# 80  My castle crumbled overnight I brought a knife...
# 81  I, I loved you in secret First sight, yeah, we...
# 82  This ain't for the best My reputation's never ...
# 83  Don't blame me, your love made me crazy If it ...
# 84  Our secret moments in a crowded room They got ...
# 85  Future I wanna be your end game I wanna be you...
# 86  No, nothing good starts in a getaway car It wa...
# 87  Gorgeous You should take it as a compliment Th...
# 88  I never trust a narcissist, but they love me S...
# 89  I'm perfectly fine, I live on my own I made up...
# 90  I don't like your little games Don't like your...
# 91  There's glitter on the floor after the party G...
# 92  See you in the dark All eyes on you, my magici...
# 93  It was so nice throwing big parties Jump into ...
# 0   I promise that you'll never find another like ...
#
#                                         song_textblob  polarity  subjectivity  \
# 0   (P, e, o, p, l, e,  , l, i, k, e,  , y, o, u, ...  0.201206      0.403947
# 1   (', C, a, u, s, e,  , b, a, b, y, ,,  , n, o, ... -0.234846      0.630275
# 2   (N, i, c, e,  , t, o,  , m, e, e, t,  , y, o, ... -0.003736      0.615789
# 3   (T, h, e,  , d, r, o, u, g, h, t,  , w, a, s, ...  0.051141      0.600347
# 4   (U, h, ,,  , u, h, ,,  , u, h,  , U, h, ,,  , ... -0.078125      0.450000
# 5   (Y, o, u,  , s, t, a, n, d,  , w, i, t, h,  , ... -0.093025      0.448425
# 6   (I, t, ', s,  , 2, :, 0, 0,  , A, M, ,,  , i, ...  0.097098      0.456215
# 7   (W, e, ', r, e,  , a, l, l,  , b, o, r, e, d, ...  0.201309      0.564463
# 8   (L, o, o, k, i, n, g,  , a, t,  , i, t,  , n, ...  0.187191      0.398589
# 9   (I,  , s, t, a, y,  , o, u, t,  , t, o, o,  , ... -0.482914      0.869336
# 10  (M, i, d, n, i, g, h, t,  , Y, o, u,  , c, o, ...  0.002435      0.239618
# 11  (C, l, e, a, r,  , b, l, u, e,  , w, a, t, e, ...  0.199935      0.444248
# 12  (W, a, l, k, i, n, g,  , t, h, r, o, u, g, h, ...  0.426636      0.658263
# 13  (H, e,  , s, a, i, d, ,,  , ", L, e, t, ', s, ...  0.135847      0.482963
# 14  (F, l, a, s, h, i, n, g,  , l, i, g, h, t, s, ... -0.022647      0.436201
# 15  (O, n, e,  , l, o, o, k, ,,  , d, a, r, k,  , ...  0.278472      0.500000
# 16  (I,  , s, e, e,  , y, o, u, r,  , f, a, c, e, ... -0.129987      0.777850
# 17  (A, n, d,  , i, t, ', s,  , a,  , s, a, d,  , ...  0.017336      0.436905
# 18  (T, h, e, r, e, ', s,  , s, o, m, e, t, h, i, ...  0.315390      0.385066
# 19  (Y, o, u,  , t, a, k, e,  , a,  , d, e, e, p, ...  0.189583      0.364931
# 20  (O, n, c, e,  , u, p, o, n,  , a,  , t, i, m, ...  0.021654      0.520076
# 21  (H, e, y,  , S, t, e, p, h, e, n, ,,  , I,  , ...  0.353889      0.717778
# 22  (W, e,  , w, e, r, e,  , b, o, t, h,  , y, o, ...  0.050000      0.455435
# 23  (I,  , t, o, o, k,  , a,  , c, h, a, n, c, e, ... -0.190594      0.533363
# 24  (I, ', m,  , f, i, v, e,  , y, e, a, r, s,  , ...  0.182857      0.472202
# 25  (H, e,  , i, s,  , s, e, n, s, i, b, l, e,  , ...  0.259165      0.643292
# 26  (S, a, y,  , y, o, u, ', r, e,  , s, o, r, r, ... -0.087897      0.437450
# 27  (Y, o, u, ', r, e,  , o, n,  , t, h, e,  , p, ...  0.215988      0.414568
# 28  (A, l, l,  , t, h, i, s,  , t, i, m, e,  , I, ...  0.039141      0.611616
# 29  (I, t,  , f, e, e, l, s,  , l, i, k, e,  , a, ...  0.151786      0.618155
# ..                                                ...       ...           ...
# 65  (W, h, y,  , w, o, u, l, d,  , y, o, u,  , w, ...  0.523529      0.525490
# 66  (I,  , d, o, n, ', t,  , k, n, o, w,  , w, h, ...  0.216111      0.700556
# 67  (Y, o, u,  , h, a, v, e,  , a,  , w, a, y,  , ...  0.247917      0.764167
# 68  (F, r, i, d, a, y,  , n, i, g, h, t,  , b, e, ... -0.003122      0.651726
# 69  (S, h, e,  , c, a, n, ', t,  , s, e, e,  , t, ...  0.288961      0.723052
# 70  (S, h, e,  , s, a, i, d, ,,  , I,  , w, a, s, ...  0.156533      0.361523
# 71  (I,  , w, a, s,  , r, i, d, i, n, g,  , s, h, ... -0.116005      0.483466
# 72  (S, t, a, t, e,  , t, h, e,  , o, b, v, i, o, ... -0.199145      0.606838
# 73  (I, t, ', s,  , s, t, r, a, n, g, e,  , t, o, ...  0.011786      0.195536
# 74  (C, o, r, y, ', s,  , e, y, e, s,  , a, r, e, ...  0.437351      0.672917
# 75  (D, r, e, w,  , l, o, o, k, s,  , a, t,  , m, ...  0.260434      0.693987
# 76  (I,  , d, i, d, n, ', t,  , k, n, o, w,  , w, ...  0.179478      0.335034
# 77  (S, e, e, m, s,  , t, h, e,  , o, n, l, y,  , ...  0.190556      0.423333
# 78  (H, e,  , s, a, i, d,  , t, h, e,  , w, a, y, ...  0.105707      0.351296
# 79  (K, n, e, w,  , h, e,  , w, a, s,  , a,  , k, ...  0.057604      0.315052
# 80  (M, y,  , c, a, s, t, l, e,  , c, r, u, m, b, ...  0.166099      0.416179
# 81  (I, ,,  , I,  , l, o, v, e, d,  , y, o, u,  , ... -0.052917      0.440926
# 82  (T, h, i, s,  , a, i, n, ', t,  , f, o, r,  , ...  0.014035      0.629825
# 83  (D, o, n, ', t,  , b, l, a, m, e,  , m, e, ,, ...  0.039025      0.607262
# 84  (O, u, r,  , s, e, c, r, e, t,  , m, o, m, e, ...  0.110345      0.696552
# 85  (F, u, t, u, r, e,  , I,  , w, a, n, n, a,  , ... -0.084320      0.344283
# 86  (N, o, ,,  , n, o, t, h, i, n, g,  , g, o, o, ...  0.139484      0.525099
# 87  (G, o, r, g, e, o, u, s,  , Y, o, u,  , s, h, ...  0.124825      0.692764
# 88  (I,  , n, e, v, e, r,  , t, r, u, s, t,  , a, ...  0.291228      0.587135
# 89  (I, ', m,  , p, e, r, f, e, c, t, l, y,  , f, ... -0.010498      0.485714
# 90  (I,  , d, o, n, ', t,  , l, i, k, e,  , y, o, ... -0.028656      0.506727
# 91  (T, h, e, r, e, ', s,  , g, l, i, t, t, e, r, ... -0.018631      0.323597
# 92  (S, e, e,  , y, o, u,  , i, n,  , t, h, e,  , ... -0.003188      0.451640
# 93  (I, t,  , w, a, s,  , s, o,  , n, i, c, e,  , ...  0.290741      0.694753
# 0   (I,  , p, r, o, m, i, s, e,  , t, h, a, t,  , ...  0.225806      0.632258
#
#     song_length  song_length_unique  uniqueness
# 0           453                 110    0.242826
# 1           470                 130    0.276596
# 2           502                 194    0.386454
# 3           274                 114    0.416058
# 4           384                 121    0.315104
# 5           295                 124    0.420339
# 6           563                 126    0.223801
# 7           402                 140    0.348259
# 8           652                 129    0.197853
# 9           595                 148    0.248739
# 10          371                 144    0.388140
# 11          278                 104    0.374101
# 12          321                 100    0.311526
# 13          357                 140    0.392157
# 14          449                 156    0.347439
# 15          371                 140    0.377358
# 16          234                 126    0.538462
# 17          269                 141    0.524164
# 18          316                 126    0.398734
# 19          407                 187    0.459459
# 20          405                 137    0.338272
# 21          395                 148    0.374684
# 22          373                 179    0.479893
# 23          350                 122    0.348571
# 24          352                 177    0.502841
# 25          271                 123    0.453875
# 26          303                 145    0.478548
# 27          397                 163    0.410579
# 28          291                 118    0.405498
# 29          377                 114    0.302387
# ..          ...                 ...         ...
# 65          224                  71    0.316964
# 66          232                  92    0.396552
# 67          242                 111    0.458678
# 68          306                 119    0.388889
# 69          248                  89    0.358871
# 70          330                 159    0.481818
# 71          365                 146    0.400000
# 72          293                 119    0.406143
# 73          347                 122    0.351585
# 74          274                 133    0.485401
# 75          287                 139    0.484321
# 76          227                  96    0.422907
# 77          245                  98    0.400000
# 78          366                 133    0.363388
# 79          429                 144    0.335664
# 80          512                 167    0.326172
# 81          427                 140    0.327869
# 82          512                 134    0.261719
# 83          479                 135    0.281837
# 84          491                 147    0.299389
# 85          719                 248    0.344924
# 86          551                 187    0.339383
# 87          386                 140    0.362694
# 88          432                 144    0.333333
# 89          476                 152    0.319328
# 90          557                 131    0.235189
# 91          369                 106    0.287263
# 92          388                 122    0.314433
# 93          393                 154    0.391858
# 0           471                 471    0.292994
#
# [95 rows x 9 columns]

# %%
# album_year = {'Taylor Swift': 2006, 'Fearless': 2008, 'Speak Now': 2010, 'Red': 2012, '1989': 2014, 'reputation': 2017}
color_dict = {'Taylor Swift': 'deepskyblue', 'Fearless': 'gold', 'Speak Now': 'mediumorchid', 'Red': 'red', '1989': 'lightskyblue', 'reputation': 'gray','ME!': 'pink'}
# album_year_df = pd.DataFrame(pd.DataFrame(album_year,index=[0]).unstack()).droplevel(level=1)
# album_year_df.columns = ['year']
# album_year_df

plt.figure(figsize=(10,5))
sns.boxplot(x = 'album', y= 'uniqueness', data = song_df, order = ['Taylor Swift','Fearless','Speak Now','Red','1989','reputation','ME!'], palette=color_dict);
plt.show()
